# %% [markdown]
# ***
# ***
#
# <img width='700' src="https://user-images.githubusercontent.com/8030363/108961534-b9a66980-7634-11eb-96e2-cc46589dcb8c.png" style="vertical-align:middle">
#
# ## Working with RDF Graphs
#
# ***
#
# **Author:** [TJCallahan](http://tiffanycallahan.com/)
# **GitHub Repository:** [PheKnowLator](https://github.com/callahantiff/PheKnowLator/wiki)
# **Wiki Page:** [OWL-NETS-2.0](https://github.com/callahantiff/PheKnowLator/wiki/OWL-NETS-2.0)
# **Release:** **[v2.0.0](https://github.com/callahantiff/PheKnowLator/wiki/v2.0.0)**
#
# <br>
#
# ### Purpose
# The goal of this notebook is to provide some examples of how to manipulate RDF ([Resource Description Framework](https://www.w3.org/RDF/)) graphs using the Python libraries [RDFLib](https://rdflib.readthedocs.io/en/stable/_modules/rdflib/compare.html) and [NetworkX](https://networkx.org/). This tutorial will cover the following concepts:
# - [Environment Set-Up](#setup)
# - [Loading Data](#data-load)
# - [Exploring Graphs](#exploring-graphs)
# - [Saving, Serializing, and Writing Graphs](#saving-output)
# - [Try it Yourself](#try-it-yourself)
#
#
# #### Resources
# - RDFLib
#   - [Getting started with RDFLib](https://rdflib.readthedocs.io/en/stable/gettingstarted.html)
# - NetworkX
#   - [Introduction to NetworkX](https://networkx.org/documentation/stable//reference/introduction.html)
#   - [Cambridge NetworkX Tutorial](https://www.cl.cam.ac.uk/teaching/1314/L109/tutorial.pdf)
# - SPARQL Query
#   - [Constructing SPARQL Queries](https://www.w3.org/2009/Talks/0615-qbe/)
#   - [SPARQL - Medium Article](https://medium.com/wallscope/constructing-sparql-queries-ca63b8b9ac02)

# %% [markdown]
# <br>
#
# ***
# ### Set-Up Environment <a class="anchor" id="setup"></a>
# ***
#
# #### Dependencies: [`pkt_kg`](https://pypi.org/project/pkt-kg/), [`networkx`](https://pypi.org/project/networkx/), [`rdflib`](https://pypi.org/project/rdflib/)
#
# To prepare for the tutorial we need to make sure that the all needed libraries are downloaded and imported. If you don't already have `pkt_kg`, `networkx` and `rdflib` installed, you can extend the code chunk below to include any libraries that you need to download. In addition to downloading needed libraries, you will also need to download graph data. Each data source is briefly described in the next section.

# %%
# # uncomment and run to install any required modules from notebooks/requirements.txt
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: Cython>=0.29.14 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (0.29.24)
# Requirement already satisfied: more-itertools in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (8.9.0)
# Requirement already satisfied: networkx in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (2.5.1)
# Requirement already satisfied: numpy>=1.18.1 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.19.2)
# Requirement already satisfied: openpyxl>=3.0.3 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (3.0.7)
# Requirement already satisfied: pandas>=1.0.5 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 6)) (1.1.5)
# Requirement already satisfied: psutil in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (5.8.0)
# Requirement already satisfied: python-json-logger in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (2.0.2)
# Requirement already satisfied: ray in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: rdflib in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 10)) (5.0.0)
# Requirement already satisfied: reactome2py in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: requests in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 12)) (2.26.0)
# Requirement already satisfied: responses==0.10.12 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 13)) (0.10.12)
# Requirement already satisfied: tqdm in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 14)) (4.62.2)
# Requirement already satisfied: urllib3 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from -r requirements.txt (line 15)) (1.26.6)
# Requirement already satisfied: six in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from responses==0.10.12->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: et-xmlfile in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from openpyxl>=3.0.3->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from pandas>=1.0.5->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from pandas>=1.0.5->-r requirements.txt (line 6)) (2021.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from requests->-r requirements.txt (line 12)) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from requests->-r requirements.txt (line 12)) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from requests->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: decorator<5,>=4.3 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from networkx->-r requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: protobuf>=3.15.3 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (3.17.3)
# Requirement already satisfied: redis>=3.5.0 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (3.5.3)
# Requirement already satisfied: attrs in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: dataclasses in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (0.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (1.0.2)
# Requirement already satisfied: click>=7.0 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (8.0.1)
# Requirement already satisfied: filelock in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (3.0.12)
# Requirement already satisfied: pyyaml in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (5.4.1)
# Requirement already satisfied: grpcio>=1.28.1 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from ray->-r requirements.txt (line 9)) (1.40.0)
# Requirement already satisfied: importlib-metadata in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from click>=7.0->ray->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: pyparsing in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from rdflib->-r requirements.txt (line 10)) (2.4.7)
# Requirement already satisfied: isodate in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from rdflib->-r requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: json5>=0.8.4 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from reactome2py->-r requirements.txt (line 11)) (0.9.6)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from importlib-metadata->click>=7.0->ray->-r requirements.txt (line 9)) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/sanya/.conda/envs/sanya_kg/lib/python3.6/site-packages (from importlib-metadata->click>=7.0->ray->-r requirements.txt (line 9)) (3.5.0)

# %%
# # if running a local version of pkt_kg, uncomment the code below
import sys
sys.path.append('../')

# %%
# import needed libraries
import networkx as nx
import os
import rdflib
from rdflib import Graph, Namespace, URIRef, BNode, Literal
from tqdm import tqdm

from pkt_kg.utils import *  # provides access to helper functions

# %%
# import built-in namespaces
from rdflib.namespace import OWL, RDF, RDFS

# create namespaces
obo = Namespace('http://purl.obolibrary.org/obo/')
entrez = Namespace('http://www.ncbi.nlm.nih.gov/gene/')

# %% [markdown]
# #### Tutorial Data
# This tutorial utilizes two separate graphs. The first graph is the [Vaccine Ontology (VO)](http://www.obofoundry.org/ontology/vo.html) and the second graph is one of the [`PheKnowlator`](https://github.com/callahantiff/PheKnowLator) builds. Each of these data sources are briefly described below:
#
# **[`Vaccine Ontology`](http://purl.obolibrary.org/obo/vo.owl)**: For this resource, we will download and utilize the [OWL](https://www.w3.org/TR/owl-features/) file provided by the Open Biomedical Ontologies Foundry. The link used to download this ontology will ensure that no matter when
#
# **[`PheKnowLator Build`](https://storage.googleapis.com/pheknowlator/archived_builds/release_v2.0.0/build_11FEB2021/knowledge_graphs/instance_builds/relations_only/owlnets/PheKnowLator_v2.0.0_full_instance_relationsOnly_noOWL_OWLNETS.nt)**: For this resources, we will utilize data from the `PheKnowLator` instance build, with directed relations, and [`OWL-NETS`](https://github.com/callahantiff/PheKnowLator/wiki/OWL-NETS-2.0) property graph conversion (`PheKnowLator_v2.0.0_full_instance_relationsOnly_noOWL_OWLNETS.nt`). To demonstrate different ways that data can be processed, we will be downloading the data in the [`ntriples`](https://www.w3.org/TR/n-triples/) format.

# %%
# Set global variables
write_location = '../temp_dir/'
if not os.path.exists(write_location):
    os.mkdir(write_location)

# %%
write_location
# Out:
# '../temp_dir/'

# %%
# download data to the temp_dir directory
graph_paths = [
    '/home/sanya/PheKnowLator/resources/ontologies/chebi_lite_with_imports.owl',
    '/home/sanya/PheKnowLator/resources/knowledge_graphs/PheKnowLator_v2.1.0_full_instance_inverseRelations_OWLNETS_NetworkxMultiDiGraph.gpickle',
    '/home/sanya/PheKnowLator/resources/knowledge_graphs/PheKnowLator_v2.1.0_full_instance_inverseRelations_OWLNETS.nt'
]

# %% [markdown]
# <br>
#
# ***
# ### Loading Data <a class="anchor" id="data-load"></a>
# ***
#
# **Relevant Documentation:** [`https://rdflib.readthedocs.io/en/stable/intro_to_parsing.html`](https://rdflib.readthedocs.io/en/stable/intro_to_parsing.html)
#
# This section demonstrates how to load data using `RDFLib`. Please note that there are many different ways that one can load data, which largely depends on the the format of the data you are trying to import. See the link above for details regarding the different types of formats that the library can import.
#
# In this tutorial we will be importing data to an `RDFLib` `Graph()` object using two different imports formats:
# 1. `vo.owl` using `xml` format
# 2. `PheKnowLator_v2.0.0_full_instance_relationsOnly_noOWL_OWLNETS.nt` using `nt` format

# %% [markdown]
# ##### Loading `vo.owl`

# %%
vo_graph = Graph()
vo_graph.parse('/home/sanya/PheKnowLator/resources/ontologies/chebi_lite_with_imports.owl', format='xml')
# Out:
# <Graph identifier=Nd6156b75e4334cc396b32ef82d93c72d (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# <br>
#
# ***
# ### Exploring Graphs <a class="anchor" id="exploring-graphs"></a>
# ***

# %% [markdown]
# Before diving into this tutorial, it's useful to review some of the tutorials on accessing and manipulating `RDFLib` `Graph()` objects. Specifically, it's useful to review the following:
# - **[RDFLib Terms](https://rdflib.readthedocs.io/en/stable/rdf_terms.html?highlight=terms)**: `URIRef()`, `Literal()`, and `BNode()`
# - **[Triple Pattern Matching](https://rdflib.readthedocs.io/en/stable/intro_to_graphs.html#basic-triple-matching)**: `graph.triples()`, `graph.subjects()`, `graph.objects()`, and `graph.predicates()`
# - **[Namespace Utilities](https://rdflib.readthedocs.io/en/stable/apidocs/rdflib.html?highlight=namespace#namespace-utilities)**: Provides description of the built-in namespaces (e.g. `OWL`, `RDF`, `RDFS`, etc...)
# - **[SPARQL Queries](https://rdflib.readthedocs.io/en/stable/intro_to_sparql.html):** `graph.query()`

# %% [markdown]
# #### Graph Descriptives
#
# The code chunks below provide different examples of how to obtain counts of different parts of the graph. Specifically, the code below demonstrates how to obtain counts of `owl:Class` and `owl:ObjectProperty`.

# %% [markdown]
# *Approach 1:* Obtain counts using a SPARQL query. `RDFLib` documentation for writing SPARQL queries can be found [here](https://rdflib.readthedocs.io/en/stable/intro_to_sparql.html).

# %%
# Approach 1: SPARQL query -- note the use of OWL and RDF built-in namespaces
class_query = vo_graph.query(
    """SELECT DISTINCT ?class
    WHERE {
      # ?class rdf:type owl:Class .}
    """, initNs={'rdf': RDF,
                 'owl': OWL}) 

print('There are {} owl:Class objects'.format(len(class_query)))
# Out:
# There are 125748 owl:Class objects

# %%
object_query = vo_graph.query(
    """SELECT DISTINCT ?object_properties
    WHERE {
      # ?object_properties rdf:type owl:ObjectProperty .}
    """, initNs={'rdf': RDF,
                 'owl': OWL}) 

print('There are {} owl:ObjectProperties objects'.format(len(object_query)))
# Out:
# There are 10 owl:ObjectProperties objects

# %% [markdown]
# *Approach 2:* Obtain counts using `RDFLib` built-in methods. Specifically, the examples below demonstrate the `subjects()` and `triples()` methods. `RDFLib` documentation for these built-in functions can be found [here](https://rdflib.readthedocs.io/en/stable/intro_to_graphs.html#graph-methods-for-accessing-triples).

# %%
# Approach 2: Iterate over RDFLib graph object
classes = list(vo_graph.subjects(RDF.type, OWL.Class))
objects = list(vo_graph.subjects(RDF.type, OWL.ObjectProperty))
triples = list(vo_graph.triples((None, None, None)))

print('There are {} triples, {} owl:Class objects, and {} owl:ObjectProperties objects'.format(len(triples),
                                                                                               len(classes),
                                                                                               len(objects)))
# Out:
# There are 1290926 triples, 125748 owl:Class objects, and 10 owl:ObjectProperties objects

# %% [markdown]
# #### Helpful Functions
# The next code sections provide examples of how to access different types of information from an `RDF` graph.

# %%
# get labels for the URI VO_0002186 -- see two different ways to reference a URI
# using obo namespace
chebi_42255_label = vo_graph.label(obo.CHEBI_42255)
print(str(chebi_42255_label))
# Out:
# (-)-epigallocatechin

# %%
# using RDFLIb URIRef term
chebi_42255_label = vo_graph.label(URIRef('http://purl.obolibrary.org/obo/CHEBI_42255'))
print(str(chebi_42255_label))
# Out:
# (-)-epigallocatechin

# %%
# get all triples that VO_0002186 participates in
chebi_42255_triples = list(vo_graph.triples((obo.CHEBI_42255, None, None))) +\
                     list(vo_graph.triples((None, None, obo.CHEBI_42255)))

for s, p, o in tqdm(chebi_42255_triples):
#     print(s, p, o)
    print(str(s).split('/')[-1], str(p).split('/')[-1], str(o).split('/')[-1] + '\n')  # converting entities to str
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 20257.68it/s]
# CHEBI_42255 rdf-schema#label (-)-epigallocatechin
#
# CHEBI_42255 rdf-schema#subClassOf CHEBI_71224
#
# CHEBI_42255 oboInOwl#inSubset chebi#3_STAR
#
# CHEBI_42255 IAO_0000115 A flavan-3,3',4',5,5',7-hexol having (2R,3R)-configuration.
#
# CHEBI_42255 oboInOwl#id CHEBI:42255
#
# CHEBI_42255 22-rdf-syntax-ns#type owl#Class
#
# CHEBI_42255 oboInOwl#hasAlternativeId CHEBI:31029
#
# CHEBI_42255 rdf-schema#subClassOf N2cd81f683eba44ce8802df17b3b3e178
#
# CHEBI_42255 oboInOwl#hasAlternativeId CHEBI:42251
#
# CHEBI_42255 rdf-schema#subClassOf N9439e4e9c3e14027a1e2330db52ccd58
#
# CHEBI_42255 rdf-schema#subClassOf CHEBI_23053
#
# CHEBI_42255 oboInOwl#hasOBONamespace chebi_ontology
#
# CHEBI_42255 rdf-schema#subClassOf N88add9e70d864fd3abfc4626cc7ab876
#
# CHEBI_42255 rdf-schema#subClassOf N2c68a2510e40482abcc069c1d85f4823
#
# Nefdd51f124664c719e362062f096041b owl#someValuesFrom CHEBI_42255
#
# Nae52f391010f46c693084f9dcbb4ce9e owl#someValuesFrom CHEBI_42255
#
# N00366c1f07de4880baf74b0bdef51d80 owl#someValuesFrom CHEBI_42255
#
# N3c63ff0871674ef3826ec3b006ad504b owl#someValuesFrom CHEBI_42255
#
# N985167e5936742fe847396dffab50e29 owl#someValuesFrom CHEBI_42255
#
# Nd16540c6434b4437b158e5fb29a5fd16 owl#someValuesFrom CHEBI_42255
#
# Nbf5d98c78393494b8d15e59b9f624a37 owl#someValuesFrom CHEBI_42255

# %%
#figure out how to identify blank nodes labels/type/identifiers

# %%
# get all owl:ObjectProperty objects
vo_obj_props = list(vo_graph.subjects(RDF.type, OWL.ObjectProperty))

for p in tqdm(vo_obj_props):
    print(p)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 34407.74it/s]
# http://purl.obolibrary.org/obo/chebi#is_enantiomer_of
# http://purl.obolibrary.org/obo/chebi#has_functional_parent
# http://purl.obolibrary.org/obo/RO_0000087
# http://purl.obolibrary.org/obo/chebi#has_major_microspecies_at_pH_7_3
# http://purl.obolibrary.org/obo/chebi#has_parent_hydride
# http://purl.obolibrary.org/obo/chebi#is_conjugate_base_of
# http://purl.obolibrary.org/obo/chebi#is_substituent_group_from
# http://purl.obolibrary.org/obo/chebi#is_conjugate_acid_of
# http://purl.obolibrary.org/obo/chebi#is_tautomer_of
# http://purl.obolibrary.org/obo/BFO_0000051

# %% [markdown]
# #### Obtaining Detailed Network Statistics
# While `RDFLib` is a great library for building `RDF` graphs, it lacks functionality to obtain some of the more traditional network statistics. In order to be able to use the `NetworkX` functions, we first need to convert the `RDFLib` `Graph()` object into a `NetworkX` [MultiDiGraph](https://networkx.github.io/documentation/stable/reference/classes/multidigraph.html). You will notice, if you read the `RDFLib` documentation that there are methods that will do this for you. In my experience, they are incredibly slow, it's much faster to use the code shown below.
#
# From [this](https://networkx.org/documentation/stable/reference/classes/multidigraph.html) `NetworkX` documentation:
# > A directed graph class that can store multiedges.
# >
# > Multiedges are multiple edges between two nodes. Each edge can hold optional data or attributes.
# >
# > A MultiDiGraph holds directed edges. Self loops are allowed.
# >
# > Nodes can be arbitrary (hashable) Python objects with optional key/value attributes. By convention None is not used as a node.
# >
# > Edges are represented as links between nodes with optional key/value attributes.

# %%
# convert RDFLib graph to Networkx MultiDiGraph
nx_graph = nx.MultiDiGraph()

for s, p, o in tqdm(vo_graph):
    nx_graph.add_edge(s, o, **{'key': p})
# Out:
# 100%|██████████| 1290926/1290926 [00:49<00:00, 26108.88it/s]

# %%
# get the number of nodes, edges, and self-loops
nodes = nx.number_of_nodes(nx_graph)
edges = nx.number_of_edges(nx_graph)
self_loops = nx.number_of_selfloops(nx_graph)

print('There are {} nodes, {} edges, and {} self-loop(s)'.format(nodes, edges, self_loops))
# Out:
# There are 564335 nodes, 1290926 edges, and 0 self-loop(s)

# %%
# get degree information
avg_degree = float(edges) / nodes

print('The Average Degree is {}'.format(avg_degree))
# Out:
# The Average Degree is 2.287517166222191

# %%
# get 5 nodes with the highest degress
n_deg = sorted([(str(x[0]), x[1]) for x in  nx_graph.degree], key=lambda x: x[1], reverse=1)[:6]

for x in n_deg:
    print('{} (degree={})'.format(x[0], x[1]))
# Out:
# chebi_ontology (degree=125759)
# http://www.w3.org/2002/07/owl#Class (degree=125748)
# http://www.w3.org/2002/07/owl#Restriction (degree=83467)
# http://purl.obolibrary.org/obo/chebi#2_STAR (degree=64632)
# http://purl.obolibrary.org/obo/chebi#3_STAR (degree=58102)
# http://purl.obolibrary.org/obo/RO_0000087 (degree=39408)

# %%
# get network density
density = nx.density(nx_graph)

print('The density of the graph is: {}'.format(density))
# Out:
# The density of the graph is: 4.0534810346748395e-06

# %%
# get connected components -- have to convert MultiDiGraph to undirected graph
nx_graph_und = nx_graph.to_undirected()

# get connected components
components = sorted(list(nx.connected_components(nx_graph_und)), key=len, reverse=True)
cc_content = {x: str(len(components[x])) + ' nodes: ' + ' | '.join(components[x]) if len(components[x]) < 500
              else len(components[x]) for x in range(len(components))}

for k, v in cc_content.items():
    if isinstance(v, int):
        print('COMPONENT: {} Consists of {} nodes'.format(str(k), str(v)))
    else:
        print('\nCOMPONENT: {} Consists of the following nodes:'.format(str(k)))
        for node in v.split(': ')[-1].split(' | '):
            print(node)
# Out:
# COMPONENT: 0 Consists of 564335 nodes

# %% [markdown]
# ##### Shortest Path
#
# This chunk shows how to find the shortest path between a starting node and all nodes reachable from that node. From [this](https://networkx.org/documentation/stable//reference/algorithms/generated/networkx.algorithms.shortest_paths.unweighted.single_source_shortest_path.html#networkx.algorithms.shortest_paths.unweighted.single_source_shortest_path) `NetworkX` page:
#
# > Compute shortest path between source and all other nodes reachable from source.
# >
# > **Parameters:**
# >   - G (NetworkX graph)
# >   - source (node label) – Starting node for path
# >   - cutoff (integer, optional) – Depth to stop the search. Only paths of length <= cutoff are returned.
# >
# > **Returns:**
# >   lengths – Dictionary, keyed by target, of shortest paths.
# >
# > **Return type:**
# > dictionary

# %%
# get shortest path from VO_0002186
chebi_42255_path = nx.single_source_shortest_path(nx_graph, obo.CHEBI_42255)

for k, v in chebi_42255_path.items():
    if k != obo.CHEBI_42255:
        print('\n{} - {} Path:'.format(str(obo.CHEBI_42255).split('/')[-1], str(k).split('/')[-1]))
        for i in v:
            print(i)
# Out:
# CHEBI_42255 - N88add9e70d864fd3abfc4626cc7ab876 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
#
# CHEBI_42255 - N9439e4e9c3e14027a1e2330db52ccd58 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
#
# CHEBI_42255 - CHEBI_23053 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
#
# CHEBI_42255 - CHEBI_71224 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
#
# CHEBI_42255 - CHEBI:42251 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# CHEBI:42251
#
# CHEBI_42255 - owl#Class Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://www.w3.org/2002/07/owl#Class
#
# CHEBI_42255 - CHEBI:42255 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# CHEBI:42255
#
# CHEBI_42255 - (-)-epigallocatechin Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# (-)-epigallocatechin
#
# CHEBI_42255 - A flavan-3,3',4',5,5',7-hexol having (2R,3R)-configuration. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# A flavan-3,3',4',5,5',7-hexol having (2R,3R)-configuration.
#
# CHEBI_42255 - N2c68a2510e40482abcc069c1d85f4823 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
#
# CHEBI_42255 - N2cd81f683eba44ce8802df17b3b3e178 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
#
# CHEBI_42255 - chebi#3_STAR Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/chebi#3_STAR
#
# CHEBI_42255 - chebi_ontology Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# chebi_ontology
#
# CHEBI_42255 - CHEBI:31029 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# CHEBI:31029
#
# CHEBI_42255 - owl#Restriction Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://www.w3.org/2002/07/owl#Restriction
#
# CHEBI_42255 - CHEBI_78295 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
#
# CHEBI_42255 - RO_0000087 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
#
# CHEBI_42255 - CHEBI_22586 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
#
# CHEBI_42255 - catechin Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# catechin
#
# CHEBI_42255 - CHEBI_72010 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
#
# CHEBI_42255 - CHEBI:23053 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# CHEBI:23053
#
# CHEBI_42255 - Members of the class of hydroxyflavan that have a flavan-3-ol skeleton and its substituted derivatives. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# Members of the class of hydroxyflavan that have a flavan-3-ol skeleton and its substituted derivatives.
#
# CHEBI_42255 - A hydroxyflavan  that is 3,4-dihydro-2H-chromene which is substituted at positions 3, 5, and 7 by hydroxy groups, and at position 2 by a 3,4,5-trihydroxyphenyl group. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# A hydroxyflavan  that is 3,4-dihydro-2H-chromene which is substituted at positions 3, 5, and 7 by hydroxy groups, and at position 2 by a 3,4,5-trihydroxyphenyl group.
#
# CHEBI_42255 - CHEBI_26195 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
#
# CHEBI_42255 - CHEBI_35681 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
#
# CHEBI_42255 - flavan-3,3',4',5,5',7-hexol Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# flavan-3,3',4',5,5',7-hexol
#
# CHEBI_42255 - CHEBI:71224 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# CHEBI:71224
#
# CHEBI_42255 - CHEBI_71227 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/CHEBI_71227
#
# CHEBI_42255 - chebi#is_enantiomer_of Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/chebi#is_enantiomer_of
#
# CHEBI_42255 - CHEBI_76924 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
#
# CHEBI_42255 - owl#AnnotationProperty Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/chebi#3_STAR
# http://www.w3.org/2002/07/owl#AnnotationProperty
#
# CHEBI_42255 - oboInOwl#SubsetProperty Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/chebi#3_STAR
# http://www.geneontology.org/formats/oboInOwl#SubsetProperty
#
# CHEBI_42255 - Manually annotated by ChEBI Team Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/chebi#3_STAR
# Manually annotated by ChEBI Team
#
# CHEBI_42255 - CHEBI:78295 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# CHEBI:78295
#
# CHEBI_42255 - CHEBI_52211 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
#
# CHEBI_42255 - Any substance that is distributed in foodstuffs. It includes materials derived from plants or animals, such as vitamins or minerals, as well as environmental contaminants. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# Any substance that is distributed in foodstuffs. It includes materials derived from plants or animals, such as vitamins or minerals, as well as environmental contaminants.
#
# CHEBI_42255 - food component Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# food component
#
# CHEBI_42255 - false Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
# false
#
# CHEBI_42255 - owl#ObjectProperty Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
# http://www.w3.org/2002/07/owl#ObjectProperty
#
# CHEBI_42255 - has_role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
# has_role
#
# CHEBI_42255 - has role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
# has role
#
# CHEBI_42255 - RO:0000087 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/RO_0000087
# RO:0000087
#
# CHEBI_42255 - CHEBI:22586 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# CHEBI:22586
#
# CHEBI_42255 - A substance that opposes oxidation or inhibits reactions brought about by dioxygen or peroxides. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# A substance that opposes oxidation or inhibits reactions brought about by dioxygen or peroxides.
#
# CHEBI_42255 - antioxidant Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# antioxidant
#
# CHEBI_42255 - CHEBI_51086 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
#
# CHEBI_42255 - CHEBI:24036 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# CHEBI:24036
#
# CHEBI_42255 - A member of the class of flavans in which one or more ring hydrogens are replaced by hydroxy groups. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# A member of the class of flavans in which one or more ring hydrogens are replaced by hydroxy groups.
#
# CHEBI_42255 - hydroxyflavan Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# hydroxyflavan
#
# CHEBI_42255 - CHEBI_38672 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
#
# CHEBI_42255 - CHEBI:72010 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# CHEBI:72010
#
# CHEBI_42255 - CHEBI_33822 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
#
# CHEBI_42255 - CHEBI_33853 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
#
# CHEBI_42255 - polyphenol Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# polyphenol
#
# CHEBI_42255 - CHEBI:26195 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# CHEBI:26195
#
# CHEBI_42255 - Members of the class of phenols that contain 2 or more benzene rings each of which is substituted by at least one hydroxy group. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# Members of the class of phenols that contain 2 or more benzene rings each of which is substituted by at least one hydroxy group.
#
# CHEBI_42255 - secondary alcohol Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# secondary alcohol
#
# CHEBI_42255 - CHEBI:13425 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:13425
#
# CHEBI_42255 - CHEBI:8741 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:8741
#
# CHEBI_42255 - CHEBI:58662 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:58662
#
# CHEBI_42255 - CHEBI:35681 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:35681
#
# CHEBI_42255 - CHEBI:26617 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:26617
#
# CHEBI_42255 - CHEBI:13686 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:13686
#
# CHEBI_42255 - CHEBI_30879 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
#
# CHEBI_42255 - CHEBI:9077 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# CHEBI:9077
#
# CHEBI_42255 - A secondary alcohol is a compound in which a hydroxy group, -OH, is attached to a saturated carbon atom which has two other carbon atoms attached to it. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# A secondary alcohol is a compound in which a hydroxy group, -OH, is attached to a saturated carbon atom which has two other carbon atoms attached to it.
#
# CHEBI_42255 - (+)-epigallocatechin Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/CHEBI_71227
# (+)-epigallocatechin
#
# CHEBI_42255 - A flavan-3,3',4',5,5',7-hexol that has (2S,3S)-configuration. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/CHEBI_71227
# A flavan-3,3',4',5,5',7-hexol that has (2S,3S)-configuration.
#
# CHEBI_42255 - Nefdd51f124664c719e362062f096041b Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/CHEBI_71227
# Nefdd51f124664c719e362062f096041b
#
# CHEBI_42255 - CHEBI:71227 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/CHEBI_71227
# CHEBI:71227
#
# CHEBI_42255 - true Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/chebi#is_enantiomer_of
# true
#
# CHEBI_42255 - is enantiomer of Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/chebi#is_enantiomer_of
# is enantiomer of
#
# CHEBI_42255 - is_enantiomer_of Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2c68a2510e40482abcc069c1d85f4823
# http://purl.obolibrary.org/obo/chebi#is_enantiomer_of
# is_enantiomer_of
#
# CHEBI_42255 - CHEBI:75766 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# CHEBI:75766
#
# CHEBI_42255 - plant metabolite Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# plant metabolite
#
# CHEBI_42255 - CHEBI:76924 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# CHEBI:76924
#
# CHEBI_42255 - CHEBI_75763 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
#
# CHEBI_42255 - CHEBI:76925 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# CHEBI:76925
#
# CHEBI_42255 - Any eukaryotic metabolite produced during a metabolic reaction in plants, the kingdom that include flowering plants, conifers and other gymnosperms. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# Any eukaryotic metabolite produced during a metabolic reaction in plants, the kingdom that include flowering plants, conifers and other gymnosperms.
#
# CHEBI_42255 - subset_property Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/chebi#3_STAR
# http://www.geneontology.org/formats/oboInOwl#SubsetProperty
# subset_property
#
# CHEBI_42255 - CHEBI_24432 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/CHEBI_24432
#
# CHEBI_42255 - chebi#1_STAR Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/chebi#1_STAR
#
# CHEBI_42255 - CHEBI:52211 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# CHEBI:52211
#
# CHEBI_42255 - physiological role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# physiological role
#
# CHEBI_42255 - A role played by the molecular entity or part thereof within a chemical context. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# A role played by the molecular entity or part thereof within a chemical context.
#
# CHEBI_42255 - CHEBI:51086 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# CHEBI:51086
#
# CHEBI_42255 - CHEBI_50906 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# http://purl.obolibrary.org/obo/CHEBI_50906
#
# CHEBI_42255 - chemical role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# chemical role
#
# CHEBI_42255 - CHEBI:38672 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# CHEBI:38672
#
# CHEBI_42255 - flavans Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# flavans
#
# CHEBI_42255 - CHEBI_38443 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
#
# CHEBI_42255 - CHEBI_26004 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_26004
#
# CHEBI_42255 - Any flavonoid with a 3,4-dihydro-2-aryl-2H-1-benzopyran skeleton and its substituted derivatives. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# Any flavonoid with a 3,4-dihydro-2-aryl-2H-1-benzopyran skeleton and its substituted derivatives.
#
# CHEBI_42255 - CHEBI_47916 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
#
# CHEBI_42255 - CHEBI_50860 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
#
# CHEBI_42255 - organic hydroxy compound Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# organic hydroxy compound
#
# CHEBI_42255 - CHEBI:33822 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# CHEBI:33822
#
# CHEBI_42255 - CHEBI_24651 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
#
# CHEBI_42255 - An organic compound having at least one hydroxy group attached to a carbon atom. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# An organic compound having at least one hydroxy group attached to a carbon atom.
#
# CHEBI_42255 - CHEBI:64710 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# CHEBI:64710
#
# CHEBI_42255 - CHEBI:13825 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# CHEBI:13825
#
# CHEBI_42255 - CHEBI_33659 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# http://purl.obolibrary.org/obo/CHEBI_33659
#
# CHEBI_42255 - CHEBI:25969 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# CHEBI:25969
#
# CHEBI_42255 - phenols Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# phenols
#
# CHEBI_42255 - CHEBI:33853 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# CHEBI:33853
#
# CHEBI_42255 - CHEBI:2857 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# CHEBI:2857
#
# CHEBI_42255 - CHEBI:13664 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# CHEBI:13664
#
# CHEBI_42255 - Organic aromatic compounds having one or more hydroxy groups attached to a benzene or other arene ring. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# Organic aromatic compounds having one or more hydroxy groups attached to a benzene or other arene ring.
#
# CHEBI_42255 - CHEBI:13804 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# CHEBI:13804
#
# CHEBI_42255 - A compound in which a hydroxy group, -OH, is attached to a saturated carbon atom. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# A compound in which a hydroxy group, -OH, is attached to a saturated carbon atom.
#
# CHEBI_42255 - alcohol Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# alcohol
#
# CHEBI_42255 - CHEBI:30879 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# CHEBI:30879
#
# CHEBI_42255 - CHEBI:22288 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# CHEBI:22288
#
# CHEBI_42255 - CHEBI:2553 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_35681
# http://purl.obolibrary.org/obo/CHEBI_30879
# CHEBI:2553
#
# CHEBI_42255 - CHEBI:75763 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# CHEBI:75763
#
# CHEBI_42255 - Any  metabolite produced during a metabolic reaction in eukaryotes, the taxon that include members of the fungi, plantae and animalia kingdoms. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# Any  metabolite produced during a metabolic reaction in eukaryotes, the taxon that include members of the fungi, plantae and animalia kingdoms.
#
# CHEBI_42255 - eukaryotic metabolite Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# eukaryotic metabolite
#
# CHEBI_42255 - CHEBI_25212 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
#
# CHEBI_42255 - A role played by the molecular entity or part thereof within a biological context. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/CHEBI_24432
# A role played by the molecular entity or part thereof within a biological context.
#
# CHEBI_42255 - biological role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/CHEBI_24432
# biological role
#
# CHEBI_42255 - CHEBI:24432 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/CHEBI_24432
# CHEBI:24432
#
# CHEBI_42255 - Preliminary entries Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N88add9e70d864fd3abfc4626cc7ab876
# http://purl.obolibrary.org/obo/CHEBI_78295
# http://purl.obolibrary.org/obo/CHEBI_52211
# http://purl.obolibrary.org/obo/chebi#1_STAR
# Preliminary entries
#
# CHEBI_42255 - role Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# http://purl.obolibrary.org/obo/CHEBI_50906
# role
#
# CHEBI_42255 - A role is particular behaviour which a material entity may exhibit. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# http://purl.obolibrary.org/obo/CHEBI_50906
# A role is particular behaviour which a material entity may exhibit.
#
# CHEBI_42255 - CHEBI:50906 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N9439e4e9c3e14027a1e2330db52ccd58
# http://purl.obolibrary.org/obo/CHEBI_22586
# http://purl.obolibrary.org/obo/CHEBI_51086
# http://purl.obolibrary.org/obo/CHEBI_50906
# CHEBI:50906
#
# CHEBI_42255 - CHEBI:38443 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# CHEBI:38443
#
# CHEBI_42255 - CHEBI_22727 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# http://purl.obolibrary.org/obo/CHEBI_22727
#
# CHEBI_42255 - 1-benzopyran Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# 1-benzopyran
#
# CHEBI_42255 - phenylpropanoid Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_26004
# phenylpropanoid
#
# CHEBI_42255 - Any organic aromatic compound with a structure based on a phenylpropane skeleton. The class includes naturally occurring phenylpropanoid esters, flavonoids, anthocyanins, coumarins and many small phenolic molecules as well as their semi-synthetic and synthetic analogues. Phenylpropanoids are also precursors of lignin. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_26004
# Any organic aromatic compound with a structure based on a phenylpropane skeleton. The class includes naturally occurring phenylpropanoid esters, flavonoids, anthocyanins, coumarins and many small phenolic molecules as well as their semi-synthetic and synthetic analogues. Phenylpropanoids are also precursors of lignin.
#
# CHEBI_42255 - CHEBI:26004 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_26004
# CHEBI:26004
#
# CHEBI_42255 - CHEBI:24044 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# CHEBI:24044
#
# CHEBI_42255 - CHEBI:47916 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# CHEBI:47916
#
# CHEBI_42255 - flavonoid Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# flavonoid
#
# CHEBI_42255 - CHEBI_72544 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# http://purl.obolibrary.org/obo/CHEBI_72544
#
# CHEBI_42255 - CHEBI:13638 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# CHEBI:13638
#
# CHEBI_42255 - Any member of the 'superclass' flavonoids whose skeleton is based on 1-benzopyran with an aryl substituent at position 2. The term was originally restricted to natural products, but is now also used to describe semi-synthetic and fully synthetic compounds. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# Any member of the 'superclass' flavonoids whose skeleton is based on 1-benzopyran with an aryl substituent at position 2. The term was originally restricted to natural products, but is now also used to describe semi-synthetic and fully synthetic compounds.
#
# CHEBI_42255 - N9c7f8648a30541adac1cbfc0ccf7e473 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# N9c7f8648a30541adac1cbfc0ccf7e473
#
# CHEBI_42255 - CHEBI:5077 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# CHEBI:5077
#
# CHEBI_42255 - Nf7f15f021031408b9fd58fb921459019 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# Nf7f15f021031408b9fd58fb921459019
#
# CHEBI_42255 - organic molecular entity Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# organic molecular entity
#
# CHEBI_42255 - CHEBI:33244 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# CHEBI:33244
#
# CHEBI_42255 - CHEBI_33582 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# http://purl.obolibrary.org/obo/CHEBI_33582
#
# CHEBI_42255 - CHEBI:25700 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# CHEBI:25700
#
# CHEBI_42255 - N2cfa8e89c88f4e3f8f305e96128a9858 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
#
# CHEBI_42255 - Any molecular entity that contains carbon. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# Any molecular entity that contains carbon.
#
# CHEBI_42255 - CHEBI:50860 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# CHEBI:50860
#
# CHEBI_42255 - CHEBI_33608 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_33608
#
# CHEBI_42255 - hydroxides Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# hydroxides
#
# CHEBI_42255 - N31547e52067841edbea880ad4267d350 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# N31547e52067841edbea880ad4267d350
#
# CHEBI_42255 - CHEBI_25806 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_25806
#
# CHEBI_42255 - CHEBI_37577 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_37577
#
# CHEBI_42255 - Hydroxides are chemical compounds containing a hydroxy group or salts containing hydroxide (OH(-)). Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# Hydroxides are chemical compounds containing a hydroxy group or salts containing hydroxide (OH(-)).
#
# CHEBI_42255 - CHEBI:24651 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# CHEBI:24651
#
# CHEBI_42255 - CHEBI_33832 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# http://purl.obolibrary.org/obo/CHEBI_33659
# http://purl.obolibrary.org/obo/CHEBI_33832
#
# CHEBI_42255 - CHEBI_33655 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# http://purl.obolibrary.org/obo/CHEBI_33659
# http://purl.obolibrary.org/obo/CHEBI_33655
#
# CHEBI_42255 - CHEBI:33659 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# http://purl.obolibrary.org/obo/CHEBI_33659
# CHEBI:33659
#
# CHEBI_42255 - organic aromatic compound Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_71224
# http://purl.obolibrary.org/obo/CHEBI_26195
# http://purl.obolibrary.org/obo/CHEBI_33853
# http://purl.obolibrary.org/obo/CHEBI_33659
# organic aromatic compound
#
# CHEBI_42255 - CHEBI:35220 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# CHEBI:35220
#
# CHEBI_42255 - CHEBI_52206 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# http://purl.obolibrary.org/obo/CHEBI_52206
#
# CHEBI_42255 - CHEBI:26619 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# CHEBI:26619
#
# CHEBI_42255 - CHEBI:25212 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# CHEBI:25212
#
# CHEBI_42255 - Any intermediate or product resulting from metabolism. The term 'metabolite' subsumes the classes commonly known as primary and secondary metabolites. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# Any intermediate or product resulting from metabolism. The term 'metabolite' subsumes the classes commonly known as primary and secondary metabolites.
#
# CHEBI_42255 - metabolite Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# N2cd81f683eba44ce8802df17b3b3e178
# http://purl.obolibrary.org/obo/CHEBI_76924
# http://purl.obolibrary.org/obo/CHEBI_75763
# http://purl.obolibrary.org/obo/CHEBI_25212
# metabolite
#
# CHEBI_42255 - CHEBI:22727 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# http://purl.obolibrary.org/obo/CHEBI_22727
# CHEBI:22727
#
# CHEBI_42255 - benzopyran Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# http://purl.obolibrary.org/obo/CHEBI_22727
# benzopyran
#
# CHEBI_42255 - CHEBI_38166 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# http://purl.obolibrary.org/obo/CHEBI_22727
# http://purl.obolibrary.org/obo/CHEBI_38166
#
# CHEBI_42255 - CHEBI_38104 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_38443
# http://purl.obolibrary.org/obo/CHEBI_22727
# http://purl.obolibrary.org/obo/CHEBI_38104
#
# CHEBI_42255 - CHEBI:72544 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# http://purl.obolibrary.org/obo/CHEBI_72544
# CHEBI:72544
#
# CHEBI_42255 - flavonoids Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# http://purl.obolibrary.org/obo/CHEBI_72544
# flavonoids
#
# CHEBI_42255 - Any organic molecular entity whose stucture is based on derivatives of a phenyl-substituted 1-phenylpropane possessing a C15 or C16 skeleton, or such a structure which is condensed with a C6-C3 lignan precursors. The term is a 'superclass' comprising all members of the classes of flavonoid, isoflavonoid, neoflavonoid, chalcones, dihydrochalcones, aurones, pterocarpan, coumestans, rotenoid, flavonolignan, homoflavonoid and flavonoid oligomers. Originally restricted to natural products, the term is also applied to synthetic compounds related to them. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# http://purl.obolibrary.org/obo/CHEBI_72544
# Any organic molecular entity whose stucture is based on derivatives of a phenyl-substituted 1-phenylpropane possessing a C15 or C16 skeleton, or such a structure which is condensed with a C6-C3 lignan precursors. The term is a 'superclass' comprising all members of the classes of flavonoid, isoflavonoid, neoflavonoid, chalcones, dihydrochalcones, aurones, pterocarpan, coumestans, rotenoid, flavonolignan, homoflavonoid and flavonoid oligomers. Originally restricted to natural products, the term is also applied to synthetic compounds related to them.
#
# CHEBI_42255 - chebi#has_functional_parent Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_38672
# http://purl.obolibrary.org/obo/CHEBI_47916
# N9c7f8648a30541adac1cbfc0ccf7e473
# http://purl.obolibrary.org/obo/chebi#has_functional_parent
#
# CHEBI_42255 - N2a56154e526b4a5898e4f685c0e79b99 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# http://purl.obolibrary.org/obo/CHEBI_33582
# N2a56154e526b4a5898e4f685c0e79b99
#
# CHEBI_42255 - CHEBI_33675 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# http://purl.obolibrary.org/obo/CHEBI_33582
# http://purl.obolibrary.org/obo/CHEBI_33675
#
# CHEBI_42255 - CHEBI:33582 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# http://purl.obolibrary.org/obo/CHEBI_33582
# CHEBI:33582
#
# CHEBI_42255 - carbon group molecular entity Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# http://purl.obolibrary.org/obo/CHEBI_33582
# carbon group molecular entity
#
# CHEBI_42255 - CHEBI_27594 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
#
# CHEBI_42255 - BFO_0000051 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/BFO_0000051
#
# CHEBI_42255 - N2e53ffeac976404984d2266109525ef3 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_33608
# N2e53ffeac976404984d2266109525ef3
#
# CHEBI_42255 - CHEBI:33608 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_33608
# CHEBI:33608
#
# CHEBI_42255 - hydrogen molecular entity Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_33608
# hydrogen molecular entity
#
# CHEBI_42255 - CHEBI_33674 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_33608
# http://purl.obolibrary.org/obo/CHEBI_33674
#
# CHEBI_42255 - CHEBI_43176 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# N31547e52067841edbea880ad4267d350
# http://purl.obolibrary.org/obo/CHEBI_43176
#
# CHEBI_42255 - oxygen molecular entity Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_25806
# oxygen molecular entity
#
# CHEBI_42255 - Ncea2e6090d8a418c9ceb7955ecb3dae9 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_25806
# Ncea2e6090d8a418c9ceb7955ecb3dae9
#
# CHEBI_42255 - CHEBI_33304 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_25806
# http://purl.obolibrary.org/obo/CHEBI_33304
#
# CHEBI_42255 - CHEBI:25806 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_25806
# CHEBI:25806
#
# CHEBI_42255 - CHEBI:37577 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_37577
# CHEBI:37577
#
# CHEBI_42255 - CHEBI_36357 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_24651
# http://purl.obolibrary.org/obo/CHEBI_37577
# http://purl.obolibrary.org/obo/CHEBI_36357
#
# CHEBI_42255 - heteroatomic molecular entity Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# ...
#
# CHEBI_42255 - CHEBI_36339 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
#
# CHEBI_42255 - Heavy nuclear particle: proton or neutron. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# Heavy nuclear particle: proton or neutron.
#
# CHEBI_42255 - nucleon Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# nucleon
#
# CHEBI_42255 - CHEBI:33253 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# CHEBI:33253
#
# CHEBI_42255 - A particle smaller than an atom. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# http://purl.obolibrary.org/obo/CHEBI_36347
# http://purl.obolibrary.org/obo/CHEBI_36342
# A particle smaller than an atom.
#
# CHEBI_42255 - subatomic particle Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# http://purl.obolibrary.org/obo/CHEBI_36347
# http://purl.obolibrary.org/obo/CHEBI_36342
# subatomic particle
#
# CHEBI_42255 - CHEBI:36342 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# http://purl.obolibrary.org/obo/CHEBI_36347
# http://purl.obolibrary.org/obo/CHEBI_36342
# CHEBI:36342
#
# CHEBI_42255 - CHEBI:36340 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_36340
# CHEBI:36340
#
# CHEBI_42255 - fermion Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_36340
# fermion
#
# CHEBI_42255 - Particle of half-integer spin quantum number following Fermi-Dirac statistics. Fermions are named after Enrico Fermi. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_36340
# Particle of half-integer spin quantum number following Fermi-Dirac statistics. Fermions are named after Enrico Fermi.
#
# CHEBI_42255 - A particle not known to have substructure. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_33233
# A particle not known to have substructure.
#
# CHEBI_42255 - CHEBI:33233 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_33233
# CHEBI:33233
#
# CHEBI_42255 - fundamental particle Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N314dd3969ba444cc91f725db4b9a3c88
# http://purl.obolibrary.org/obo/CHEBI_10545
# http://purl.obolibrary.org/obo/CHEBI_36338
# http://purl.obolibrary.org/obo/CHEBI_33233
# fundamental particle
#
# CHEBI_42255 - baryon Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# baryon
#
# CHEBI_42255 - Baryon is a fermion that does experience the strong force (strong interaction). The term is derived from the Greek betaalpharhoupsilonsigma (heavy). Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# Baryon is a fermion that does experience the strong force (strong interaction). The term is derived from the Greek betaalpharhoupsilonsigma (heavy).
#
# CHEBI_42255 - CHEBI_36344 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
#
# CHEBI_42255 - CHEBI:36339 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# CHEBI:36339
#
# CHEBI_42255 - CHEBI_36343 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# http://purl.obolibrary.org/obo/CHEBI_36343
#
# CHEBI_42255 - hadron Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# hadron
#
# CHEBI_42255 - CHEBI:36344 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# CHEBI:36344
#
# CHEBI_42255 - Hadron is a subatomic particle which experiences the strong force. Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# Hadron is a subatomic particle which experiences the strong force.
#
# CHEBI_42255 - CHEBI:36343 Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# http://purl.obolibrary.org/obo/CHEBI_36343
# CHEBI:36343
#
# CHEBI_42255 - A subatomic particle known to have substructure (i.e. consisting of smaller particles). Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# http://purl.obolibrary.org/obo/CHEBI_36343
# A subatomic particle known to have substructure (i.e. consisting of smaller particles).
#
# CHEBI_42255 - composite particle Path:
# http://purl.obolibrary.org/obo/CHEBI_42255
# http://purl.obolibrary.org/obo/CHEBI_23053
# http://purl.obolibrary.org/obo/CHEBI_72010
# http://purl.obolibrary.org/obo/CHEBI_33822
# http://purl.obolibrary.org/obo/CHEBI_50860
# N2cfa8e89c88f4e3f8f305e96128a9858
# http://purl.obolibrary.org/obo/CHEBI_27594
# http://purl.obolibrary.org/obo/CHEBI_25585
# http://purl.obolibrary.org/obo/CHEBI_33250
# N96526f28ec5b4d699b6260567e04b10d
# http://purl.obolibrary.org/obo/CHEBI_33252
# Nf5245d2609df4364a713a1270cf53cf3
# http://purl.obolibrary.org/obo/CHEBI_33253
# http://purl.obolibrary.org/obo/CHEBI_36339
# http://purl.obolibrary.org/obo/CHEBI_36344
# http://purl.obolibrary.org/obo/CHEBI_36343
# composite particle

# %% [markdown]
# <br>
#
# ***
# ### Saving, Serializing, and Writing Graphs <a class="anchor" id="saving-output"></a>
# ***
#
# Below, I provide examples for how to save data using `NetworkX` and `RDFLib`.

# %% [markdown]
# #### NetworkX
# **Documentation:** [Reading and Writing Data](https://networkx.org/documentation/stable//reference/readwrite/index.html?highlight=write%20data)
#
# Here, I provide an example of how to save the `MultiDiGraph` version of the `vo_graph` object so it can be used in the future without having to create it from the `RDFLib` graph object.

# %%
write_location
# Out:
# '../temp_dir/'

# %%
# save multidigraph version of graph
nx.write_gpickle(nx_graph, write_location + 'chebi_lite_NetworkxMultiDiGraph.gpickle')

# read in multidigraph version of graph
# nx_graph = nx.read_gpickle(write_location + 'vo_NetworkxMultiDiGraph.gpickle')

# %% [markdown]
# #### RDFLib
# **Documentation:** [Graph Serialization](https://rdflib.readthedocs.io/en/latest/apidocs/rdflib.html#rdflib.graph.Graph.serialize)
#
# Here, I provide an example of how to save the `vo_graph` object as an `OWL` file and as an `n-triples` file.

# %%
# save vo_graph as `ntriple` format
vo_graph.serialize(write_location + 'chebi_lite_graph_data.nt', format='nt')

# %%
# save vo_graph as OWL (i.e. RDF/XML)
vo_graph.serialize(write_location + 'vo_graph_data.owl', format='xml')

# %% [markdown]
# <br>
#
# ***
# ### Try it Out for Yourself - Explore the PheKnowLator Graph Build <a class="anchor" id="try-it-yourself"></a>
# ***
#
# You will notice that while we downloaded the `pkt_kg` graph data `PheKnowLator_v2.0.0_full_instance_relationsOnly_noOWL_OWLNETS.nt`, we never used it. The remainder of this tutorial is left for you. I encourage you to use the functionality introduced above to explore this graph. If you do something interesting and want to share it, please make a pull-request and add it to this tutorial!

# %% [markdown]
# ##### Loading `PheKnowLator_v2.0.0_full_instance_relationsOnly_noOWL_OWLNETS.nt`
#
# Please note that running the chunk below can take up to 45 min as the file is 2.0 GB.

# %%
graph_paths
# Out:
# ['/home/sanya/PheKnowLator/resources/ontologies/chebi_lite_with_imports.owl',
#  '/home/sanya/PheKnowLator/resources/knowledge_graphs/PheKnowLator_v2.1.0_full_instance_inverseRelations_OWLNETS_NetworkxMultiDiGraph.gpickle',
#  '/home/sanya/PheKnowLator/resources/knowledge_graphs/PheKnowLator_v2.1.0_full_instance_inverseRelations_OWLNETS.nt']

# %%
pkt_graph = Graph()
pkt_graph.parse(graph_paths[2], format='nt')
# Out:
# <Graph identifier=N4ce77680959c4b2dafa7ab3f8f17ce71 (<class 'rdflib.graph.Graph'>)>

# %%
# get basic descriptive statistics
nodes = set(list(pkt_graph.subjects()) + list(pkt_graph.objects()))
rels = set(list(pkt_graph.predicates()))

# print stats
print('Graph Stats: {} triples, {} nodes, {} predicates'.format(len(pkt_graph), len(nodes), len(rels)))
# Out:
# Graph Stats: 4760203 triples, 743772 nodes, 222 predicates

# %%
#find identifier from label - useful for NPs
greentea_uri = rdflib.term.URIRef('http://napdi.org/napdi_srs_imports:camellia_sinensis_leaf')

# %%
obo.CHEBI_8871
# Out:
# rdflib.term.URIRef('http://purl.obolibrary.org/obo/CHEBI_8871')

# %%
# get all triples that VO_0002186 participates in
greentea_triples = list(pkt_graph.triples((greentea_uri, None, None))) +\
                     list(pkt_graph.triples((None, None, greentea_uri)))

print(len(greentea_triples))
# Out:
# 8

# %%
# get all triples that VO_0002186 participates in
chebi_8871_triples = list(pkt_graph.triples((obo.CHEBI_8871, None, None))) +\
                     list(pkt_graph.triples((None, None, obo.CHEBI_8871)))

print(len(chebi_8871_triples))
# Out:
# 714

# %%
for s, p, o in tqdm(greentea_triples):
#     print(s, p, o)
    print(str(s).split('/')[-1], str(p).split('/')[-1], str(o).split('/')[-1] + '\n')  # converting entities to str
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 11911.41it/s]
# napdi_srs_imports:camellia_sinensis_leaf RO_0002180 CHEBI_70255
#
# napdi_srs_imports:camellia_sinensis_leaf RO_0002162 NCBITaxon_4442
#
# napdi_srs_imports:camellia_sinensis_leaf rdf-schema#subClassOf CHEBI_24431
#
# napdi_srs_imports:camellia_sinensis_leaf BFO_0000050 napdi_srs_imports:camellia_sinensis_whole
#
# napdi_srs_imports:camellia_sinensis_leaf RO_0002180 CHEBI_90
#
# napdi_srs_imports:camellia_sinensis_leaf RO_0002180 napdi_srs_imports:epigallocatechin_gallate
#
# napdi_srs_imports:camellia_sinensis_leaf RO_0002180 CHEBI_42255
#
# napdi_srs_imports:camellia_sinensis_leaf RO_0002180 CHEBI_68330

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4ea9028ce95b> in <module>
#       1 # get shortest path from VO_0002186
# ----> 2 chebi_90_path = nx.single_source_shortest_path(nx_graph, obo.CHEBI_90)
#       3
#       4 for k, v in chebi_90_path.items():
#       5     if k != obo.CHEBI_90:
#
# NameError: name 'nx_graph' is not defined

# %% [markdown]
# ##### Create Subgraph
#
# Create a subgraph from the `pkt_kg` build that only contains the following types of edges: `gene-drug`, `drug-disease`, `gene-disease`. To do this, we filter the graph first by relation and then by node types. Examples for each relation type are listed below:
#
# `drug-gene`:
# - Find all triples that include the predicate: *interacts with* (`obo:RO_0002434`)
#   - Only keep subjects with the following URI: `obo:CHEBI_XXXXXXX`
#   - Only keep objects with the following URI: `http://www.ncbi.nlm.nih.gov/gene/`
#
# `drug-disease`:
# - Find all triples that include the predicate: *substance that treats* (`obo:RO_0002606`)
#   - Only keep subjects with the following URI: `obo:CHEBI_XXXXXXX`
#   - Only keep objects with the following URI: `obo:MONDO_XXXXXXX`
#
# `gene-disease`:
# - Find all triples that include the predicate: *causes or contributes to* (`obo.RO_0003302`)
#   - Only keep subjects with the following URI: `http://www.ncbi.nlm.nih.gov/gene/X`
#   - Only keep objects with the following URI: `obo:MONDO_XXXXXXX`
#
#
# Also add *inhibits* and *molecularly_interacts_with*: obo.RO_0002449 and obo.RO_0002436

# %%
def filters_edge_data(graph, relation, subj, obj):
    """Method takes an input RDFLib graph and filters it using an the input relation, subj, and obj variables.
    
    Args:
        graph: An RDFLib Graph object.
        relation: A URIRef object containing a Relation Ontology relation. 
        subj: A URIRef object containing information to filter subjects by.
        obj: A URIRef object containing information to filter objects by.
    
    Returns:
        filtered_edges: 
    """
    
    filtered_triples = []

    for s, p, o in tqdm(graph):
        if p == relation:
            if str(s).startswith(str(subj)) and str(o).startswith(str(obj)):
                filtered_triples += [(s, p, o)]
    
    return filtered_triples

# %%
# get gene-drug edges - then keep subjects with 
drug_gene_triples = filters_edge_data(graph=pkt_graph,
                                      relation=obo.RO_0002434,
                                      subj=obo.CHEBI,
                                      obj=entrez)

print('There are {} drug-gene edges'.format(len(drug_gene_triples)))
# Out:
# 100%|██████████| 29634791/29634791 [04:35<00:00, 107558.70it/s]
# There are 0 drug-gene edges

# %%
# get drug-disease edges
drug_disease_triples = filters_edge_data(graph=pkt_graph,
                                         relation=obo.RO_0002606,
                                         subj=obo.CHEBI,
                                         obj=obo.MONDO)

print('There are {} drug-disease edges'.format(len(drug_disease_triples)))
# Out:
# 100%|██████████| 29634791/29634791 [03:27<00:00, 142926.99it/s]
# There are 0 drug-disease edges

# %%
# get gene-disease edges
gene_disease_triples = filters_edge_data(graph=pkt_graph,
                                         relation=obo.RO_0003302,
                                         subj=entrez,
                                         obj=obo.MONDO)

print('There are {} gene-disease edges'.format(len(gene_disease_triples)))
# Out:
# 100%|██████████| 29634791/29634791 [03:31<00:00, 140153.78it/s]
# There are 0 gene-disease edges

# %%
# get protein-chemical edges
protein_drug_triples = filters_edge_data(graph=pkt_graph,
                                         relation=obo.RO_0002434,
                                         subj=obo.CHEBI,
                                         obj=obo.)

print('There are {} protein-drug edges'.format(len(protien_drug_triples)))

# %%
# combine triples into single graph
filtered_edges = drug_gene_triples + drug_disease_triples + gene_disease_triples
gene_drug_disease_graph = adds_edges_to_graph(Graph(), filtered_edges)

print('The drug-gene-disease Subgraph contains {} triples'.format(len(gene_drug_disease_graph)))
# Out:
# 0it [00:00, ?it/s]
# The drug-gene-disease Subgraph contains 0 triples

# %% [markdown]
# ##### Convert Subgraph to NetworkX MultiDiGraph

# %%
# convert RDFLib graph to Networkx MultiDiGraph
nx_graph_dgd = nx.read_gpickle(graph_paths[1])

# %% [markdown]
# ##### Get Graph Descriptives

# %%
# get the number of nodes, edges, and self-loops
nodes = nx.number_of_nodes(nx_graph_dgd)
edges = nx.number_of_edges(nx_graph_dgd)
avg_degree = float(edges) / nodes

print('There are {} nodes, {} edges, and has an average degree of {}'.format(nodes, edges, avg_degree))
# Out:
# There are 743772 nodes, 4759979 edges, and has an average degree of 6.3997824602163025

# %%
# get 5 nodes with the highest degress
n_deg = sorted([(str(x[0]), x[1]) for x in  nx_graph_dgd.degree], key=lambda x: x[1], reverse=1)[:6]

for x in n_deg:
    print('{} (degree={})'.format(x[0], x[1]))
# Out:
# http://purl.obolibrary.org/obo/SO_0001217 (degree=184732)
# http://purl.obolibrary.org/obo/SO_0000673 (degree=180194)
# http://purl.obolibrary.org/obo/NCBITaxon_9606 (degree=85578)
# http://purl.obolibrary.org/obo/PR_000000001 (degree=57850)
# http://purl.obolibrary.org/obo/NCBITaxon_10090 (degree=52725)
# http://purl.obolibrary.org/obo/NCBITaxon_3702 (degree=37565)

# %%
# get connected components -- have to convert MultiDiGraph to undirected graph
nx_graph_und = nx_graph_dgd.to_undirected()

# get connected components
components = sorted(list(nx.connected_components(nx_graph_und)), key=len, reverse=True)
cc_content = {x: str(len(components[x])) + ' nodes: ' + ' | '.join(components[x]) if len(components[x]) < 500
              else len(components[x]) for x in range(len(components))}

for k, v in cc_content.items():
    if isinstance(v, int):
        print('COMPONENT: {} Consists of {} nodes'.format(str(k), str(v)))
    else:
        print('\nCOMPONENT: {} Consists of the following nodes:'.format(str(k)))
        for node in v.split(': ')[-1].split(' | '):
            print(node)
# Out:
# COMPONENT: 0 Consists of 743772 nodes

# %% [markdown]
# ##### Explore Graph
#
# Example shown below searches for all shortest paths between valporic acid ([CHEBI_39867](https://www.ebi.ac.uk/chebi/searchId.do?chebiId=CHEBI:39867)) and all other targets in the graph. This search returns several results, one example is shown below:
#
# > **Path between CHEBI_39867 - MONDO_0012489:**
# > http://purl.obolibrary.org/obo/CHEBI_39867
# > http://www.ncbi.nlm.nih.gov/gene/1413
# > http://purl.obolibrary.org/obo/MONDO_0012489
#
#
# Where [entrez gene 1413](http://www.ncbi.nlm.nih.gov/gene/1413) is CRYBA4 (crystallin beta A4) and [MONDO_0012489](http://www.ontobee.org/ontology/MONDO?iri=http://purl.obolibrary.org/obo/MONDO_0012489) is early-onset non-syndromic cataract caused by mutation in `CRYBA4`. A quick Googling returns several relevant results to connect these entities.

# %%
#paths between 
1. camellia sinensis/camellia sinensis leaf/EGCG
2. rosuvastatin, simvastatin, nadolol, warfarin, sildenafile, raloxifene, tacrolimus
3. CYP3A4 obo.PR_P08684 and risperidone obo.CHEBI_8871 edges

# %%
# perform bidirectional search for path between -- epilepsy and valporic acid
nx.bidirectional_shortest_path(nx_graph_dgd, obo.CHEBI_90, greentea_uri)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# <ipython-input-32-79660d8ccee9> in <module>
#       1 # perform bidirectional search for path between -- epilepsy and valporic acid
# ----> 2 nx.bidirectional_shortest_path(nx_graph_dgd, obo.CHEBI_90, greentea_uri)
#
# ~/.conda/envs/sanya_kg/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/unweighted.py in bidirectional_shortest_path(G, source, target)
#     222
#     223     # call helper to do the real work
# --> 224     results = _bidirectional_pred_succ(G, source, target)
#     225     pred, succ, w = results
#     226
#
# ~/.conda/envs/sanya_kg/lib/python3.6/site-packages/networkx/algorithms/shortest_paths/unweighted.py in _bidirectional_pred_succ(G, source, target)
#     290                         return pred, succ, w
#     291
# --> 292     raise nx.NetworkXNoPath(f"No path between {source} and {target}.")
#     293
#     294
#
# NetworkXNoPath: No path between http://purl.obolibrary.org/obo/CHEBI_90 and http://napdi.org/napdi_srs_imports:camellia_sinensis_leaf.

# %%
# look at shortest path between 
shortest_paths = nx.shortest_path(nx_graph_dgd, source=obo.CHEBI_39867)

for k, v in shortest_paths.items():
    if k != obo.CHEBI_39867:
        print('\n{} - {} Path:'.format(str(obo.CHEBI_39867).split('/')[-1], str(k).split('/')[-1]))
        for i in v:
            print(i)
# Out:
# CHEBI_39867 - 10814 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10814
#
# CHEBI_39867 - 29034 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/29034
#
# CHEBI_39867 - 64786 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/64786
#
# CHEBI_39867 - 84875 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/84875
#
# CHEBI_39867 - 342574 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/342574
#
# CHEBI_39867 - 126299 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/126299
#
# CHEBI_39867 - 4145 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/4145
#
# CHEBI_39867 - 26817 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/26817
#
# CHEBI_39867 - 116447 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/116447
#
# CHEBI_39867 - 93517 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/93517
#
# CHEBI_39867 - 7222 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/7222
#
# CHEBI_39867 - 441531 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/441531
#
# CHEBI_39867 - GO_0034404 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0034404
#
# CHEBI_39867 - GO_0060429 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0060429
#
# CHEBI_39867 - 8706 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/8706
#
# CHEBI_39867 - 7421 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/7421
#
# CHEBI_39867 - 3452 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/3452
#
# CHEBI_39867 - 127062 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/127062
#
# CHEBI_39867 - 9423 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/9423
#
# CHEBI_39867 - GO_0005802 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0005802
#
# CHEBI_39867 - 54961 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/54961
#
# CHEBI_39867 - MONDO_0012245 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/MONDO_0012245
#
# CHEBI_39867 - 23014 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/23014
#
# CHEBI_39867 - GO_0018205 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0018205
#
# CHEBI_39867 - GO_0046872 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0046872
#
# CHEBI_39867 - 390113 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/390113
#
# CHEBI_39867 - 728039 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/728039
#
# CHEBI_39867 - 728741 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/728741
#
# CHEBI_39867 - 6358 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/6358
#
# CHEBI_39867 - GO_0007049 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0007049
#
# CHEBI_39867 - GO_0009725 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0009725
#
# CHEBI_39867 - 84814 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/84814
#
# CHEBI_39867 - GO_0006486 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0006486
#
# CHEBI_39867 - 51237 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/51237
#
# CHEBI_39867 - 5992 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/5992
#
# CHEBI_39867 - MONDO_0009675 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/MONDO_0009675
#
# CHEBI_39867 - 7546 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/7546
#
# CHEBI_39867 - 10609 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10609
#
# CHEBI_39867 - 619505 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/619505
#
# CHEBI_39867 - 10629 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10629
#
# CHEBI_39867 - 644054 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/644054
#
# CHEBI_39867 - 2091 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/2091
#
# CHEBI_39867 - 26074 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/26074
#
# CHEBI_39867 - 84464 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/84464
#
# CHEBI_39867 - 51571 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/51571
#
# CHEBI_39867 - 83696 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/83696
#
# CHEBI_39867 - 23167 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/23167
#
# CHEBI_39867 - 84536 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/84536
#
# CHEBI_39867 - 146712 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/146712
#
# CHEBI_39867 - 2122 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/
Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/5905
#
# CHEBI_39867 - PR_P00352 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/PR_P00352
#
# CHEBI_39867 - GO_0009968 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0009968
#
# CHEBI_39867 - 377007 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/377007
#
# CHEBI_39867 - 57332 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/57332
#
# CHEBI_39867 - 641517 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/641517
#
# CHEBI_39867 - 149076 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/149076
#
# CHEBI_39867 - 2852 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/2852
#
# CHEBI_39867 - 143 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/143
#
# CHEBI_39867 - GO_0022839 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0022839
#
# CHEBI_39867 - GO_0043413 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0043413
#
# CHEBI_39867 - GO_0099512 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0099512
#
# CHEBI_39867 - 9069 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/9069
#
# CHEBI_39867 - GO_0006950 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0006950
#
# CHEBI_39867 - 10317 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10317
#
# CHEBI_39867 - 92370 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/92370
#
# CHEBI_39867 - 653656 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/653656
#
# CHEBI_39867 - 1413 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/1413
#
# CHEBI_39867 - 49860 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/49860
#
# CHEBI_39867 - 283999 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/283999
#
# CHEBI_39867 - GO_0005488 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0005488
#
# CHEBI_39867 - 54090 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/54090
#
# CHEBI_39867 - 112936 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/112936
#
# CHEBI_39867 - 79776 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/79776
#
# CHEBI_39867 - 57477 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/57477
#
# CHEBI_39867 - 3146 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/3146
#
# CHEBI_39867 - 150864 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/150864
#
# CHEBI_39867 - 55897 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/55897
#
# CHEBI_39867 - 8801 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/8801
#
# CHEBI_39867 - PR_P04114 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/PR_P04114
#
# CHEBI_39867 - 6119 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/6119
#
# CHEBI_39867 - 338440 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/338440
#
# CHEBI_39867 - 84450 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/84450
#
# CHEBI_39867 - 10239 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10239
#
# CHEBI_39867 - PR_Q9NYQ3 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/PR_Q9NYQ3
#
# CHEBI_39867 - 8676 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/8676
#
# CHEBI_39867 - MONDO_0016064 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/MONDO_0016064
#
# CHEBI_39867 - 389119 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/389119
#
# CHEBI_39867 - 10161 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/10161
#
# CHEBI_39867 - GO_0009152 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0009152
#
# CHEBI_39867 - 164592 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/164592
#
# CHEBI_39867 - GO_0016042 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0016042
#
# CHEBI_39867 - 9103 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/9103
#
# CHEBI_39867 - 11033 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/11033
#
# CHEBI_39867 - 53339 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/53339
#
# CHEBI_39867 - 57489 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/57489
#
# CHEBI_39867 - 8424 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/8424
#
# CHEBI_39867 - 7784 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/7784
#
# CHEBI_39867 - 55660 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/55660
#
# CHEBI_39867 - 1737 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/1737
#
# CHEBI_39867 - PR_P19419 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/PR_P19419
#
# CHEBI_39867 - 23125 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/23125
#
# CHEBI_39867 - 388182 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/388182
#
# CHEBI_39867 - MONDO_0002492 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/MONDO_0002492
#
# CHEBI_39867 - 23116 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/23116
#
# CHEBI_39867 - 3483 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://www.ncbi.nlm.nih.gov/gene/3483
#
# CHEBI_39867 - GO_0030695 Path:
# http://purl.obolibrary.org/obo/CHEBI_39867
# http://purl.obolibrary.org/obo/GO_0030695

# %% [markdown]
# ##### Save Output

# %%
# save subgraph
gene_drug_disease_graph.serialize(write_location + 'pkt_DrugGeneDisease_subgraph.nt', format='nt')
nx.write_gpickle(nx_graph_dgd, write_location + 'pkt_DrugGeneDisease_NetworkxMultiDiGraph.gpickle')
